# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

penguins = sns.load_dataset("penguins")

# Draw a nested barplot by species and sex
g = sns.catplot(
    data=penguins, kind="bar",
    x="species", y="body_mass_g", hue="sex",
    ci="sd", palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("", "Body mass (g)")
g.legend.set_title("")

# %%
import pandas as pd


us_mh1 = 0.118736383442
us_mh2 = 0.125906394199
us_mh3 = 0.167037861915

us_server_to_agent_mh1 = 0.0136165577342
us_server_to_agent_mh2 = 0.00856954515491
us_server_to_agent_mh3 = 0.0207869339272


# initialize list of lists
data = [['MH1', 'CVI-SLAM', 0.119, 0.697], ['MH2', 'CVI-SLAM', 0.135, 0.707], ['MH3', 'CVI-SLAM', 0.151, 0.720], ['MH1', 'Ours', 0.119, 0.014], ['MH2', 'Ours', 0.126, 0.009], ['MH3', 'Ours', 0.167, 0.021]]



# Create the pandas DataFrame
df = pd.DataFrame(data, columns = ['sequence', 'method', 'agent_to_server', 'server_to_agent'])
df

sns.set_theme(style="white", context="talk")

f, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 6), sharex=True)

g = sns.barplot(y="agent_to_server", x="sequence", hue="method", data=df,
             palette="coolwarm",ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
ax1.set_ylabel("Agent to Server [MB/s]")
ax1.set_xlabel("")
# plt.legend(bbox_to_anchor=(2.05, 1), loc=3, borderaxespad=0.)


g2 = sns.barplot(y="server_to_agent", x="sequence", hue="method", data=df,
             palette="coolwarm", ax=ax2)
ax2.axhline(0, color="k", clip_on=False)
ax2.set_ylabel("Server to Agent [MB/s]")
ax2.set_xlabel("EuRoC Sequence")

plt.legend([],[], frameon=False)

sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=3)

for p in g.patches:
    g.annotate(format(p.get_height(), '.3f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=19,
                   xytext = (0, 8), 
                   textcoords = 'offset points')

for p in g2.patches:
    g2.annotate(format(p.get_height(), '.3f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=19,
                   xytext = (0, 8), 
                   textcoords = 'offset points')

box = g.get_position()
# g.set_position([box.x0, box.y0, box.width * 0.85, box.height]) # resize position

# Put a legend to the right side
g.legend(loc='center right', bbox_to_anchor=(0.68, 1.03), ncol=2)
plt.savefig('saving-a-seaborn-plot-as-pdf-file.pdf')

# %%
import pandas as pd


us_mh1 = 0.118736383442
us_mh2 = 0.125906394199
us_mh3 = 0.167037861915

us_server_to_agent_mh1 = 0.0136165577342
us_server_to_agent_mh2 = 0.00550296638102
us_server_to_agent_mh3 = 0.0207869339272


# initialize list of lists
data = [['MH1', 'CVI-SLAM', 0.119, 0.697], ['MH2', 'CVI-SLAM', 0.135, 0.707], ['MH3', 'CVI-SLAM', 0.151, 0.720], ['MH1', 'Ours', 0.119, 0.014], ['MH2', 'Ours', 0.126, 0.005], ['MH3', 'Ours', 0.167, 0.021]]
data2 = [['MH1', 'Agent to Server', 'CVI-SLAM', 0.119],
         ['MH1', 'Server to Agent', 'CVI-SLAM', 0.697],
         ['MH2', 'Agent to Server', 'CVI-SLAM', 0.135],
         ['MH2', 'Server to Agent', 'CVI-SLAM', 0.707],
         ['MH3', 'Agent to Server', 'CVI-SLAM', 0.151],
         ['MH3', 'Server to Agent', 'CVI-SLAM', 0.720]]
data3 =[['MH1', 'Agent to Server', 'Ours', 0.119],
         ['MH1', 'Server to Agent', 'Ours', 0.014],
         ['MH2', 'Agent to Server', 'Ours', 0.126],
         ['MH2', 'Server to Agent', 'Ours', 0.005],
         ['MH3', 'Agent to Server', 'Ours', 0.167],
         ['MH3', 'Server to Agent', 'Ours', 0.021]]

# Create the pandas DataFrame
# df = pd.DataFrame(data, columns = ['sequence', 'method', 'agent_to_server', 'server_to_agent'])
df = pd.DataFrame(data2, columns = ['sequence', 'direction', 'method', 'value'])
df2 = pd.DataFrame(data3, columns = ['sequence', 'direction', 'method', 'value'])

sns.set_theme(style="white", context="talk")

f, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 6), sharex=True)

g = sns.barplot(y="value", x="sequence", hue="direction", data=df,
             palette="coolwarm",ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
ax1.set_ylabel("CVI-SLAM [MB/s]")
ax1.set_xlabel("")
# plt.legend(bbox_to_anchor=(2.05, 1), loc=3, borderaxespad=0.)


g2 = sns.barplot(y="value", x="sequence", hue="direction", data=df2,
             palette="coolwarm", ax=ax2)
ax2.axhline(0, color="k", clip_on=False)
ax2.set_ylabel("Ours [MB/s]")
ax2.set_xlabel("EuRoC Sequence")

plt.legend([],[], frameon=False)

sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=3)

for p in g.patches:
    g.annotate(format(p.get_height(), '.2f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=19,
                   xytext = (0, -12), 
                   textcoords = 'offset points')

for p in g2.patches:
    g2.annotate(format(p.get_height(), '.3f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=19,
                   xytext = (0, 8), 
                   textcoords = 'offset points')

box = g.get_position()
# g.set_position([box.x0, box.y0, box.width * 0.85, box.height]) # resize position

# Put a legend to the right side
# g.legend(loc='center right', bbox_to_anchor=(0.68, 1.1), ncol=2)
g.legend(loc='center right', bbox_to_anchor=(0.72, 1.1), ncol=2)

# %%
# Out:
# '3.3.4'
